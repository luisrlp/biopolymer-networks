# %% [markdown]
# # Affine Network with compliant Crosslinkers - Angular Integration
#
# - Notebook for efficient UMAT analysis and material parameter sensitivity studies.

# %%
# !f2py -c -m umatpy py_anl_ai.f90 umat_anl_ai.f90
# Out:
# running build
# running config_cc
# unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# build_src
# building extension "umatpy" sources
# f2py options: []
# f2py:> /tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpymodule.c
# creating /tmp/tmpmvezsz89/src.linux-x86_64-3.6
# Reading fortran codes...
# 	Reading file 'py_anl_ai.f90' (format:free)
# {'before': '', 'this': 'use', 'after': ',intrinsic :: iso_fortran_env '}
# Line #3 in py_anl_ai.f90:"use,intrinsic :: ISO_Fortran_env "
# 	analyzeline: Could not crack the use statement.
# 	Reading file 'aba_param.inc' (format:fix)
# Line #15 in py_anl_ai.f90:"PARAMETER(NTENS = 6, NSTATEV = NSDV, NSHR=3) "
# 	determineexprtype: could not determine expressions ('nsdv') type.
# analyzeline: Failed to evaluate 'nsdv'. Ignoring: name 'nsdv' is not defined
# 	Reading file 'umat_anl_ai.f90' (format:free)
# Line #15 in umat_anl_ai.f90:"PARAMETER (HALF=0.5d0,THIRD=1.d0/3.d0) "
# 	determineexprtype: could not determine expressions ('1.d0/3.d0') type.
# analyzeline: Failed to evaluate '1.d0/3.d0'. Ignoring: invalid syntax (<string>, line 1)
# 	Reading file 'aba_param.inc' (format:fix)
# 	Reading file 'aba_param.inc' (format:fix)
# Post-processing...
# 	Block: umatpy
# 			Block: run_umat_py
# In: :umatpy:py_anl_ai.f90:run_umat_py
# get_useparameters: no module global info used by run_umat_py
# 			Block: global
# 			Block: indexx
# 			Block: pull2
# 			Block: csfilfic
# 			Block: setjr
# 			Block: spectral
# 			Block: jacobi
# 			Block: eigsrt
# 			Block: invariants
# 			Block: pk2isomatfic
# 			Block: deffil
# 			Block: fslip
# 			Block: sdvread
# 			Block: isomat
# 			Block: setvol
# 			Block: getoutdir
# 			Block: bangle
# 			Block: contraction42
# 			Block: sliding
# 			Block: onem
# 			Block: factorial
# 			Block: csisomatfic
# 			Block: hfilfic
# 			Block: pull4
# 			Block: metiso
# 			Block: sdvwrite
# 			Block: matinv3d
# 			Block: uexternaldb
# 			Block: projeul
# 			Block: sigiso
# 			Block: projlag
# 			Block: relax
# 			Block: vol
# 			Block: umat
# 			Block: stretch
# 			Block: initialize
# 			Block: matinv3dd
# 			Block: matinv2d
# 			Block: mdet
# 			Block: onem0
# 			Block: erfi
# 			Block: sigisomatfic
# 			Block: pullforce
# 			Block: sigvol
# 			Block: visco
# 			Block: sigfilfic
# 			Block: hvread
# 			Block: hvwrite
# 			Block: icos_shape
# 			Block: icos_size
# 			Block: sphere01_triangle_project
# 			Block: sphere01_triangle_vertices_to_sides
# 			Block: sphere01_triangle_sides_to_angles
# 			Block: sphere01_triangle_vertices_to_area
# 			Block: sphere01_triangle_angles_to_area
# In: :umatpy:umat_anl_ai.f90:sphere01_triangle_angles_to_area
# get_parameters: got "invalid syntax (<string>, line 1)" on '3.141592653589793d+00'
# 			Block: polyterm_exponent
# 			Block: polyterm_value_3d
# 			Block: r8_gamma
# In: :umatpy:umat_anl_ai.f90:r8_gamma
# get_parameters: got "invalid syntax (<string>, line 1)" on '2.22d-16'
# In: :umatpy:umat_anl_ai.f90:r8_gamma
# get_parameters: got "invalid syntax (<string>, line 1)" on '3.1415926535897932384626434d+00'
# In: :umatpy:umat_anl_ai.f90:r8_gamma
# get_parameters: got "invalid syntax (<string>, line 1)" on '0.9189385332046727417803297d+00'
# In: :umatpy:umat_anl_ai.f90:r8_gamma
# get_parameters: got "invalid syntax (<string>, line 1)" on '171.624d+00'
# In: :umatpy:umat_anl_ai.f90:r8_gamma
# get_parameters: got "invalid syntax (<string>, line 1)" on '1.0d+30'
# In: :umatpy:umat_anl_ai.f90:r8_gamma
# get_parameters: got "invalid syntax (<string>, line 1)" on '2.23d-308'
# 			Block: r8_uniform_01
# 			Block: r8vec_norm
# 			Block: r8vec_polarize
# 			Block: s_cat
# 			Block: sphere01_monomial_integral
# In: :umatpy:umat_anl_ai.f90:sphere01_monomial_integral
# get_parameters: got "invalid syntax (<string>, line 1)" on '3.141592653589793d+00'
# 			Block: xit
# 			Block: phifunc
# 			Block: fil
# 			Block: deformation
# 			Block: contraction44
# 			Block: affclnetfic_discrete
# In: :umatpy:umat_anl_ai.f90:affclnetfic_discrete
# get_parameters: got "invalid syntax (<string>, line 1)" on '3.141592653589793d+00'
# 			Block: cmatisomatfic
# 			Block: metvol
# 			Block: density
# 			Block: evalg
# 			Block: pk2vol
# 			Block: rotation
# 			Block: pk2iso
# 			Block: setiso
# 			Block: push4
# 			Block: contraction22
# 			Block: push2
# 			Block: contraction24
# 			Block: chemicalstat
# Post-processing (stage 2)...
# 	Block: umatpy
# 		Block: unknown_interface
# 			Block: run_umat_py
# 			Block: global
# 			Block: indexx
# 			Block: pull2
# 			Block: csfilfic
# 			Block: setjr
# 			Block: spectral
# 			Block: jacobi
# 			Block: eigsrt
# 			Block: invariants
# 			Block: pk2isomatfic
# 			Block: deffil
# 			Block: fslip
# 			Block: sdvread
# 			Block: isomat
# 			Block: setvol
# 			Block: getoutdir
# 			Block: bangle
# 			Block: contraction42
# 			Block: sliding
# 			Block: onem
# 			Block: factorial
# 			Block: csisomatfic
# 			Block: hfilfic
# 			Block: pull4
# 			Block: metiso
# 			Block: sdvwrite
# 			Block: matinv3d
# 			Block: uexternaldb
# 			Block: projeul
# 			Block: sigiso
# 			Block: projlag
# 			Block: relax
# 			Block: vol
# 			Block: umat
# 			Block: stretch
# 			Block: initialize
# 			Block: matinv3dd
# 			Block: matinv2d
# 			Block: mdet
# 			Block: onem0
# 			Block: erfi
# 			Block: sigisomatfic
# 			Block: pullforce
# 			Block: sigvol
# 			Block: visco
# 			Block: sigfilfic
# 			Block: hvread
# 			Block: hvwrite
# 			Block: icos_shape
# 			Block: icos_size
# 			Block: sphere01_triangle_project
# 			Block: sphere01_triangle_vertices_to_sides
# 			Block: sphere01_triangle_sides_to_angles
# 			Block: sphere01_triangle_vertices_to_area
# 			Block: sphere01_triangle_angles_to_area
# 			Block: polyterm_exponent
# 			Block: polyterm_value_3d
# 			Block: r8_gamma
# 			Block: r8_uniform_01
# 			Block: r8vec_norm
# 			Block: r8vec_polarize
# 			Block: s_cat
# 			Block: sphere01_monomial_integral
# 			Block: xit
# 			Block: phifunc
# 			Block: fil
# 			Block: deformation
# 			Block: contraction44
# 			Block: affclnetfic_discrete
# 			Block: cmatisomatfic
# 			Block: metvol
# 			Block: density
# 			Block: evalg
# 			Block: pk2vol
# 			Block: rotation
# 			Block: pk2iso
# 			Block: setiso
# 			Block: push4
# 			Block: contraction22
# 			Block: push2
# 			Block: contraction24
# 			Block: chemicalstat
# Building modules...
# 	Building module "umatpy"...
# 		Constructing wrapper function "run_umat_py"...
# 		  stress = run_umat_py(props,dfgrd1,time,dtime,kstep,[nprops,ndi])
# 		Constructing wrapper function "indexx"...
# 		  stress,ddsdde = indexx(sig,tng,ntens,[ndi])
# 		Constructing wrapper function "pull2"...
# 		  pk = pull2(sig,finv,det,[ndi])
# 		Constructing wrapper function "csfilfic"...
# 		  cfic = csfilfic(rho,lambda,dw,ddw,m,rw,[ndi])
# 		Constructing wrapper function "setjr"...
# 		  cjr = setjr(sigma,unit2,[ndi])
# 		Constructing wrapper function "spectral"...
# 		  spectral(a,d,v)
# 		Constructing wrapper function "jacobi"...
# 		  d,v,nrot = jacobi(a,n,[np])
# 		Constructing wrapper function "eigsrt"...
# 		  eigsrt(d,v,n,[np])
# 		Constructing wrapper function "invariants"...
# 		  inv1,inv2 = invariants(a,[ndi])
# 		Constructing wrapper function "pk2isomatfic"...
# 		  fic = pk2isomatfic(diso,cbar,cbari1,unit2,[ndi])
# 		Constructing wrapper function "deffil"...
# 		  lambda,m = deffil(m0,f,[ndi])
# 		Constructing wrapper function "fslip"...
# 		  fbar,det = fslip(f,[ndi])
# 		Constructing wrapper function "sdvread"...
# 		  sdvread(statev)
# 		Constructing wrapper function "isomat"...
# 		  sseiso,diso = isomat(c10,c01,cbari1,cbari2)
# 		Constructing wrapper function "setvol"...
# 		  cvol = setvol(pv,ppv,unit2,unit4s,[ndi])
# 		Constructing wrapper function "getoutdir"...
# 		  lenoutdir = getoutdir(outdir)
# 		Constructing wrapper function "bangle"...
# 		  ang = bangle(f,mf,noel,pdir,[ndi])
# 		Constructing wrapper function "contraction42"...
# 		  s = contraction42(lt,rt,[ndi])
# 		Constructing wrapper function "sliding"...
# 		  ffc,ru = sliding(ffc0,ru0,ffcmax,fric,frac,dtime)
# 		Constructing wrapper function "onem"...
# 		  a,aa,aas = onem(ndi)
# 		Constructing wrapper function "factorial"...
# 		  fact = factorial(term)
# 		Constructing wrapper function "csisomatfic"...
# 		  csisomatfic(cisomatfic,cmisomatfic,distgr,det,[ndi])
# 		Constructing wrapper function "hfilfic"...
# 		  h,hh = hfilfic(pp,lambda,m,rw,[ndi])
# 		Constructing wrapper function "pull4"...
# 		  mat = pull4(spatial,finv,det,[ndi])
# 		Constructing wrapper function "metiso"...
# 		  cmiso = metiso(cmfic,pl,pkiso,pkfic,c,unit2,det,[ndi])
# 		Constructing wrapper function "sdvwrite"...
# 		  statev = sdvwrite(det)
# 		Constructing wrapper function "matinv3d"...
# 		  a_inv = matinv3d(a,[ndi])
# 		Constructing wrapper function "uexternaldb"...
# 		  uexternaldb(lop,lrestart,time,dtime,kstep,kinc)
# 		Constructing wrapper function "projeul"...
# 		  pe = projeul(a,aa,[ndi])
# 		Constructing wrapper function "sigiso"...
# 		  sigiso(siso,sfic,pe,[ndi])
# 		Constructing wrapper function "projlag"...
# 		  pl = projlag(c,aa,[ndi])
# 		Constructing wrapper function "relax"...
# 		  qv,hv,aux1 = relax(hv0,pkiso,dtime,tau,teta,[ndi])
# 		Constructing wrapper function "vol"...
# 		  ssev,pv,ppv = vol(k,det)
# 		Constructing wrapper function "umat"...
# 		  umat(stress,statev,ddsdde,sse,spd,scd,rpl,ddsddt,drplde,drpldt,stran,dstran,time,dtime,temp,dtemp,predef,dpred,cmname,ndi,nshr,props,coords,drot,pnewdt,celent,dfgrd0,dfgrd1,noel,npt,layer,kspt,kstep,kinc,[ntens,nstatev,nprops])
# 		Constructing wrapper function "stretch"...
# 		  u,v = stretch(c,b,[ndi])
# 		Constructing wrapper function "initialize"...
# 		  statev = initialize()
# 		Constructing wrapper function "matinv3dd"...
# 		  a_inv,det_a,istat = matinv3dd(a)
# 		Constructing wrapper function "matinv2d"...
# 		  a_inv,det_a,istat = matinv2d(a)
# 		Constructing wrapper function "mdet"...
# 		  det = mdet(a)
# 		Constructing wrapper function "onem0"...
# 		  a = onem0()
# 		Constructing wrapper function "erfi"...
# 		  erf = erfi(b)
# 		Constructing wrapper function "sigisomatfic"...
# 		  sigisomatfic(sfic,pkfic,f,det,[ndi])
# 		Constructing wrapper function "pullforce"...
# 		  zero0 = pullforce(a,b,machep,t,lambda,lambda0,l,r0,mu0,beta,b0)
# 		Constructing wrapper function "sigvol"...
# 		  svol = sigvol(pv,unit2,[ndi])
# 		Constructing wrapper function "visco"...
# 		  pk,cmat = visco(vv,pkvol,pkiso,cmatvol,cmatiso,dtime,vscprops,statev,[ndi])
# 		Constructing wrapper function "sigfilfic"...
# 		  sfic = sigfilfic(rho,lambda,dw,m,rw,[ndi])
# 		Constructing wrapper function "hvread"...
# 		  hv = hvread(statev,v1,ndi)
# 		Constructing wrapper function "hvwrite"...
# 		  statev = hvwrite(hv,v1,[ndi])
# 		Constructing wrapper function "icos_shape"...
# 		  icos_shape(point_coord,edge_point,face_order,face_point,[point_num,edge_num,face_num,face_order_max])
# 		Constructing wrapper function "icos_size"...
# 		  icos_size(point_num,edge_num,face_num,face_order_max)
# 		Constructing wrapper function "sphere01_triangle_project"...
# 		  sphere01_triangle_project(a_xyz,b_xyz,c_xyz,f1,f2,f3,node_xyz)
# 		Constructing wrapper function "sphere01_triangle_vertices_to_sides"...
# 		  sphere01_triangle_vertices_to_sides(v1,v2,v3,as,bs,cs)
# 		Constructing wrapper function "sphere01_triangle_sides_to_angles"...
# 		  sphere01_triangle_sides_to_angles(as,bs,cs,a,b,c)
# 		Constructing wrapper function "sphere01_triangle_vertices_to_area"...
# 		  sphere01_triangle_vertices_to_area(v1,v2,v3,area)
# 		Constructing wrapper function "sphere01_triangle_angles_to_area"...
# 		  sphere01_triangle_angles_to_area(a,b,c,area)
# 		Constructing wrapper function "polyterm_exponent"...
# 		  polyterm_exponent(action,e)
# 		Constructing wrapper function "polyterm_value_3d"...
# 		  polyterm_value_3d(x,f,[n])
# 		Creating wrapper for Fortran function "r8_gamma"("r8_gamma")...
# 		Constructing wrapper function "r8_gamma"...
# 		  r8_gamma = r8_gamma(x)
# 		Creating wrapper for Fortran function "r8_uniform_01"("r8_uniform_01")...
# 		Constructing wrapper function "r8_uniform_01"...
# 		  r8_uniform_01 = r8_uniform_01(seed)
# 		Creating wrapper for Fortran function "r8vec_norm"("r8vec_norm")...
# 		Constructing wrapper function "r8vec_norm"...
# 		  r8vec_norm = r8vec_norm(a,[n])
# 		Constructing wrapper function "r8vec_polarize"...
# 		  r8vec_polarize(a,p,a_normal,a_parallel,[n])
# 		Constructing wrapper function "s_cat"...
# 		  s_cat(s1,s2,s3)
# 		Constructing wrapper function "sphere01_monomial_integral"...
# 		  sphere01_monomial_integral(e,integral)
# 		Constructing wrapper function "xit"...
# 		  xit()
# 		Constructing wrapper function "phifunc"...
# 		  f,df = phifunc(phi,args,[nargs])
# 		Constructing wrapper function "fil"...
# 		  f,ff,dw,ddw = fil(lambda,lambda0,ll,r0,mu0,beta,b0)
# 		Constructing wrapper function "deformation"...
# 		  c,b = deformation(f,[ndi])
# 		Constructing wrapper function "contraction44"...
# 		  s = contraction44(lt,rt,[ndi])
# 		Constructing wrapper function "affclnetfic_discrete"...
# 		  sfic,cfic = affclnetfic_discrete(f,filprops,affprops,efi,noel,det,prefdir,[ndi])
# 		Constructing wrapper function "cmatisomatfic"...
# 		  cmatisomatfic(cmisomatfic,cbar,cbari1,cbari2,diso,unit2,unit4,det,[ndi])
# 		Constructing wrapper function "metvol"...
# 		  cvol = metvol(c,pv,ppv,det,[ndi])
# 		Constructing wrapper function "density"...
# 		  rho = density(ang,bb,erfi)
# 		Constructing wrapper function "evalg"...
# 		  g = evalg(f,lambda,lambda0,l,r0,mu0,beta,b0)
# 		Constructing wrapper function "pk2vol"...
# 		  pkvol = pk2vol(pv,c,det,[ndi])
# 		Constructing wrapper function "rotation"...
# 		  r = rotation(f,u,[ndi])
# 		Constructing wrapper function "pk2iso"...
# 		  pkiso = pk2iso(pkfic,pl,det,[ndi])
# 		Constructing wrapper function "setiso"...
# 		  ciso = setiso(cfic,pe,siso,sfic,unit2,[ndi])
# 		Constructing wrapper function "push4"...
# 		  spatial = push4(mat,f,det,[ndi])
# 		Constructing wrapper function "contraction22"...
# 		  aux = contraction22(lt,rt,[ndi])
# 		Constructing wrapper function "push2"...
# 		  sig = push2(pk,f,det,[ndi])
# 		Constructing wrapper function "contraction24"...
# 		  s = contraction24(lt,rt,[ndi])
# 		Constructing wrapper function "chemicalstat"...
# 		  frac = chemicalstat(frac0,k,dtime)
# 		Constructing COMMON block support for "kfil"...
# 		  mf0
# 		Constructing COMMON block support for "kfilr"...
# 		  rw
# 		Constructing COMMON block support for "kfilp"...
# 		  prefdir
# 		Constructing F90 module support for "global"...
# 		  Variables: nelem nsdv nterm factor one two three four six zero half third dir2
# 	Wrote C/API module "umatpy" to file "/tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpymodule.c"
# 	Fortran 77 wrappers are saved to "/tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpy-f2pywrappers.f"
# 	Fortran 90 wrappers are saved to "/tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpy-f2pywrappers2.f90"
#   adding '/tmp/tmpmvezsz89/src.linux-x86_64-3.6/fortranobject.c' to sources.
#   adding '/tmp/tmpmvezsz89/src.linux-x86_64-3.6' to include_dirs.
# copying /usr/local/lib64/python3.6/site-packages/numpy/f2py/src/fortranobject.c -> /tmp/tmpmvezsz89/src.linux-x86_64-3.6
# copying /usr/local/lib64/python3.6/site-packages/numpy/f2py/src/fortranobject.h -> /tmp/tmpmvezsz89/src.linux-x86_64-3.6
#   adding '/tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpy-f2pywrappers.f' to sources.
#   adding '/tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpy-f2pywrappers2.f90' to sources.
# build_src: building npy-pkg config files
# running build_ext
# customize UnixCCompiler
# customize UnixCCompiler using build_ext
# get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'nv', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
# customize Gnu95FCompiler
# Found executable /usr/bin/gfortran
# customize Gnu95FCompiler
# customize Gnu95FCompiler using build_ext
# building 'umatpy' extension
# compiling C sources
# C compiler: gcc -pthread -Wno-unused-result -Wsign-compare -DDYNAMIC_ANNOTATIONS_ENABLED=1 -DNDEBUG -O2 -g -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -fexceptions -fstack-protector-strong -grecord-gcc-switches -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -D_GNU_SOURCE -fPIC -fwrapv -O2 -g -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -fexceptions -fstack-protector-strong -grecord-gcc-switches -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -D_GNU_SOURCE -fPIC -fwrapv -O2 -g -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -fexceptions -fstack-protector-strong -grecord-gcc-switches -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -D_GNU_SOURCE -fPIC -fwrapv -fPIC
#
# creating /tmp/tmpmvezsz89/tmp
# creating /tmp/tmpmvezsz89/tmp/tmpmvezsz89
# creating /tmp/tmpmvezsz89/tmp/tmpmvezsz89/src.linux-x86_64-3.6
# compile options: '-I/tmp/tmpmvezsz89/src.linux-x86_64-3.6 -I/usr/local/lib64/python3.6/site-packages/numpy/core/include -I/usr/include/python3.6m -c'
# gcc: /tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpymodule.c
# gcc: /tmp/tmpmvezsz89/src.linux-x86_64-3.6/fortranobject.c
# In file included from /usr/local/lib64/python3.6/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /usr/local/lib64/python3.6/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib64/python3.6/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from /tmp/tmpmvezsz89/src.linux-x86_64-3.6/fortranobject.h:13,
#                  from /tmp/tmpmvezsz89/src.linux-x86_64-3.6/fortranobject.c:2:
# /usr/local/lib64/python3.6/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# In file included from /usr/local/lib64/python3.6/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /usr/local/lib64/python3.6/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib64/python3.6/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from /tmp/tmpmvezsz89/src.linux-x86_64-3.6/fortranobject.h:13,
#                  from /tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpymodule.c:16:
# /usr/local/lib64/python3.6/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# /tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpymodule.c:219:12: warning: ‘f2py_size’ defined but not used [-Wunused-function]
#  static int f2py_size(PyArrayObject* var, ...)
#             ^~~~~~~~~
# compiling Fortran 90 module sources
# Fortran f77 compiler: /usr/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: /usr/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: /usr/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# compile options: '-I/tmp/tmpmvezsz89/src.linux-x86_64-3.6 -I/usr/local/lib64/python3.6/site-packages/numpy/core/include -I/usr/include/python3.6m -c'
# extra options: '-J/tmp/tmpmvezsz89/ -I/tmp/tmpmvezsz89/'
# gfortran:f90: umat_anl_ai.f90
# umat_anl_ai.f90:2064:2:
#
#  30    CONTINUE
#   1
# Warning: Label 30 at (1) defined but not used [-Wunused-label]
# umat_anl_ai.f90:3826:58:
#
#  DOUBLE PRECISION :: pd(3),lambda_pref,prefdir0(3),ang_pref
#                                                           1
# Warning: Unused variable ‘ang_pref’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3824:39:
#
#  DOUBLE PRECISION :: vara,avga,maxa,aux0,ffic,suma,rho0,dirmax(ndi)
#                                        1
# Warning: Unused variable ‘aux0’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3821:67:
#
#  DOUBLE PRECISION :: l,r0f,r0,mu0,b0,beta,lambda0,rho,n,fi,ffi,dtime
#                                                                    1
# Warning: Unused variable ‘dtime’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3824:44:
#
#  DOUBLE PRECISION :: vara,avga,maxa,aux0,ffic,suma,rho0,dirmax(ndi)
#                                             1
# Warning: Unused variable ‘ffic’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3823:36:
#
#  DOUBLE PRECISION :: bdisp,fric,ffmax,ang, frac(4),ru
#                                     1
# Warning: Unused variable ‘ffmax’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3823:49:
#
#  DOUBLE PRECISION :: bdisp,fric,ffmax,ang, frac(4),ru
#                                                  1
# Warning: Unused variable ‘frac’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3823:30:
#
#  DOUBLE PRECISION :: bdisp,fric,ffmax,ang, frac(4),ru
#                               1
# Warning: Unused variable ‘fric’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3817:13:
#
#  INTEGER :: i1,j1,k1,l1,m1, im1
#              1
# Warning: Unused variable ‘i1’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3817:30:
#
#  INTEGER :: i1,j1,k1,l1,m1, im1
#                               1
# Warning: Unused variable ‘im1’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3824:54:
#
#  DOUBLE PRECISION :: vara,avga,maxa,aux0,ffic,suma,rho0,dirmax(ndi)
#                                                       1
# Warning: Unused variable ‘rho0’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3823:52:
#
#  DOUBLE PRECISION :: bdisp,fric,ffmax,ang, frac(4),ru
#                                                     1
# Warning: Unused variable ‘ru’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3820:44:
#
#  DOUBLE PRECISION :: aux,lambdai,dwi,ddwi,rwi,lambdaic
#                                             1
# Warning: Unused variable ‘rwi’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3858:21:
#
#    real ( kind = 8 ) v
#                      1
# Warning: Unused variable ‘v’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3824:24:
#
#  DOUBLE PRECISION :: vara,avga,maxa,aux0,ffic,suma,rho0,dirmax(ndi)
#                         1
# Warning: Unused variable ‘vara’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:670:30:
#
#  DOUBLE PRECISION :: c(ndi,ndi),egvc(ndi,ndi),egvl(ndi)
#                               1
# Warning: Unused variable ‘c’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:670:44:
#
#  DOUBLE PRECISION :: c(ndi,ndi),egvc(ndi,ndi),egvl(ndi)
#                                             1
# Warning: Unused variable ‘egvc’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:670:54:
#
#  DOUBLE PRECISION :: c(ndi,ndi),egvc(ndi,ndi),egvl(ndi)
#                                                       1
# Warning: Unused variable ‘egvl’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:653:23:
#
#  SUBROUTINE bangle(ang,f,mf,noel,pdir,ndi)
#                        1
# Warning: Unused dummy argument ‘f’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:668:20:
#
#  INTEGER :: inoel,i,j
#                     1
# Warning: Unused variable ‘j’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:653:31:
#
#  SUBROUTINE bangle(ang,f,mf,noel,pdir,ndi)
#                                1
# Warning: Unused dummy argument ‘noel’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:4084:55:
#
#  SUBROUTINE cmatisomatfic(cmisomatfic,cbar,cbari1,cbari2,  &
#                                                        1
# Warning: Unused dummy argument ‘cbari2’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:562:25:
#
#  SUBROUTINE sdvread(statev)
#                          1
# Warning: Unused dummy argument ‘statev’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:970:52:
#
#  SUBROUTINE metiso(cmiso,cmfic,pl,pkiso,pkfic,c,unit2,det,ndi)
#                                                     1
# Warning: Unused dummy argument ‘unit2’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1085:46:
#
#  SUBROUTINE uexternaldb(lop,lrestart,time,dtime,kstep,kinc)
#                                               1
# Warning: Unused dummy argument ‘dtime’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1109:26:
#
#  INTEGER :: lenjobdir,i,j,k
#                           1
# Warning: Unused variable ‘k’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:1085:57:
#
#  SUBROUTINE uexternaldb(lop,lrestart,time,dtime,kstep,kinc)
#                                                          1
# Warning: Unused dummy argument ‘kinc’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1085:52:
#
#  SUBROUTINE uexternaldb(lop,lrestart,time,dtime,kstep,kinc)
#                                                     1
# Warning: Unused dummy argument ‘kstep’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1085:35:
#
#  SUBROUTINE uexternaldb(lop,lrestart,time,dtime,kstep,kinc)
#                                    1
# Warning: Unused dummy argument ‘lrestart’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1085:40:
#
#  SUBROUTINE uexternaldb(lop,lrestart,time,dtime,kstep,kinc)
#                                         1
# Warning: Unused dummy argument ‘time’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1302:10:
#
#      celent,dfgrd0,dfgrd1,noel,npt,layer,kspt,kstep,kinc)
#           1
# Warning: Unused dummy argument ‘celent’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1368:48:
#
#      ciso(ndi,ndi,ndi,ndi),cmiso(ndi,ndi,ndi,ndi),  &
#                                                 1
# Warning: Unused variable ‘cmiso’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:1300:58:
#
#      stran,dstran,time,dtime,temp,dtemp,predef,dpred,cmname,  &
#                                                           1
# Warning: Unused dummy argument ‘cmname’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1364:48:
#
#      cvol(ndi,ndi,ndi,ndi),cmvol(ndi,ndi,ndi,ndi)
#                                                 1
# Warning: Unused variable ‘cmvol’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:1301:46:
#
#      ndi,nshr,ntens,nstatev,props,nprops,coords,drot,pnewdt,  &
#                                               1
# Warning: Unused dummy argument ‘coords’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1392:58:
#
#  DOUBLE PRECISION :: stest(ndi,ndi), ctest(ndi,ndi,ndi,ndi)
#                                                           1
# Warning: Unused variable ‘ctest’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:1391:28:
#
#      ddpkdde(ndi,ndi,ndi,ndi)
#                             1
# Warning: Unused variable ‘ddpkdde’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:1299:60:
#
#  SUBROUTINE umat(stress,statev,ddsdde,sse,spd,scd, rpl,ddsddt,drplde,drpldt,  &
#                                                             1
# Warning: Unused dummy argument ‘ddsddt’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1302:17:
#
#      celent,dfgrd0,dfgrd1,noel,npt,layer,kspt,kstep,kinc)
#                  1
# Warning: Unused dummy argument ‘dfgrd0’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1300:51:
#
#      stran,dstran,time,dtime,temp,dtemp,predef,dpred,cmname,  &
#                                                    1
# Warning: Unused dummy argument ‘dpred’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1301:51:
#
#      ndi,nshr,ntens,nstatev,props,nprops,coords,drot,pnewdt,  &
#                                                    1
# Warning: Unused dummy argument ‘drot’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1299:67:
#
#  SUBROUTINE umat(stress,statev,ddsdde,sse,spd,scd, rpl,ddsddt,drplde,drpldt,  &
#                                                                    1
# Warning: Unused dummy argument ‘drplde’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1299:74:
#
#  SUBROUTINE umat(stress,statev,ddsdde,sse,spd,scd, rpl,ddsddt,drplde,drpldt,  &
#                                                                           1
# Warning: Unused dummy argument ‘drpldt’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1300:16:
#
#      stran,dstran,time,dtime,temp,dtemp,predef,dpred,cmname,  &
#                 1
# Warning: Unused dummy argument ‘dstran’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1300:38:
#
#      stran,dstran,time,dtime,temp,dtemp,predef,dpred,cmname,  &
#                                       1
# Warning: Unused dummy argument ‘dtemp’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1300:27:
#
#      stran,dstran,time,dtime,temp,dtemp,predef,dpred,cmname,  &
#                            1
# Warning: Unused dummy argument ‘dtime’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1302:55:
#
#      celent,dfgrd0,dfgrd1,noel,npt,layer,kspt,kstep,kinc)
#                                                        1
# Warning: Unused dummy argument ‘kinc’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1302:44:
#
#      celent,dfgrd0,dfgrd1,noel,npt,layer,kspt,kstep,kinc)
#                                             1
# Warning: Unused dummy argument ‘kspt’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1302:39:
#
#      celent,dfgrd0,dfgrd1,noel,npt,layer,kspt,kstep,kinc)
#                                        1
# Warning: Unused dummy argument ‘layer’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1302:33:
#
#      celent,dfgrd0,dfgrd1,noel,npt,layer,kspt,kstep,kinc)
#                                  1
# Warning: Unused dummy argument ‘npt’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1301:12:
#
#      ndi,nshr,ntens,nstatev,props,nprops,coords,drot,pnewdt,  &
#             1
# Warning: Unused dummy argument ‘nshr’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1377:36:
#
#  DOUBLE PRECISION :: phi,r0,r0c,r0f,p,etac
#                                     1
# Warning: Unused variable ‘p’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:1301:58:
#
#      ndi,nshr,ntens,nstatev,props,nprops,coords,drot,pnewdt,  &
#                                                           1
# Warning: Unused dummy argument ‘pnewdt’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1300:45:
#
#      stran,dstran,time,dtime,temp,dtemp,predef,dpred,cmname,  &
#                                              1
# Warning: Unused dummy argument ‘predef’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1377:26:
#
#  DOUBLE PRECISION :: phi,r0,r0c,r0f,p,etac
#                           1
# Warning: Unused variable ‘r0’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:1299:53:
#
#  SUBROUTINE umat(stress,statev,ddsdde,sse,spd,scd, rpl,ddsddt,drplde,drpldt,  &
#                                                      1
# Warning: Unused dummy argument ‘rpl’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1299:48:
#
#  SUBROUTINE umat(stress,statev,ddsdde,sse,spd,scd, rpl,ddsddt,drplde,drpldt,  &
#                                                 1
# Warning: Unused dummy argument ‘scd’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1299:44:
#
#  SUBROUTINE umat(stress,statev,ddsdde,sse,spd,scd, rpl,ddsddt,drplde,drpldt,  &
#                                             1
# Warning: Unused dummy argument ‘spd’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1299:40:
#
#  SUBROUTINE umat(stress,statev,ddsdde,sse,spd,scd, rpl,ddsddt,drplde,drpldt,  &
#                                         1
# Warning: Unused dummy argument ‘sse’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1392:34:
#
#  DOUBLE PRECISION :: stest(ndi,ndi), ctest(ndi,ndi,ndi,ndi)
#                                   1
# Warning: Unused variable ‘stest’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:1300:9:
#
#      stran,dstran,time,dtime,temp,dtemp,predef,dpred,cmname,  &
#          1
# Warning: Unused dummy argument ‘stran’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:1300:32:
#
#      stran,dstran,time,dtime,temp,dtemp,predef,dpred,cmname,  &
#                                 1
# Warning: Unused dummy argument ‘temp’ at (1) [-Wunused-dummy-argument]
# umat_anl_ai.f90:3629:42:
#
#  real(8)  mu,mu0,rgas,theta,chi,vmol,gshear,kbulk
#                                           1
# Warning: Unused variable ‘gshear’ declared at (1) [-Wunused-variable]
# umat_anl_ai.f90:3625:19:
#
#  INTEGER :: material
#                    1
# Warning: Unused variable ‘material’ declared at (1) [-Wunused-variable]
# compiling Fortran sources
# Fortran f77 compiler: /usr/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: /usr/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: /usr/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# compile options: '-I/tmp/tmpmvezsz89/src.linux-x86_64-3.6 -I/usr/local/lib64/python3.6/site-packages/numpy/core/include -I/usr/include/python3.6m -c'
# extra options: '-J/tmp/tmpmvezsz89/ -I/tmp/tmpmvezsz89/'
# gfortran:f90: py_anl_ai.f90
# py_anl_ai.f90:24:21:
#
#  CHARACTER*40 FILENAME
#                      1
# Warning: Unused variable ‘filename’ declared at (1) [-Wunused-variable]
# py_anl_ai.f90:22:10:
#
#  integer ii
#           1
# Warning: Unused variable ‘ii’ declared at (1) [-Wunused-variable]
# py_anl_ai.f90:23:24:
#
#  CHARACTER*8 CMNAME, stri
#                         1
# Warning: Unused variable ‘stri’ declared at (1) [-Wunused-variable]
# gfortran:f90: /tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpy-f2pywrappers2.f90
# gfortran:f77: /tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpy-f2pywrappers.f
# /usr/bin/gfortran -Wall -g -Wall -g -shared /tmp/tmpmvezsz89/tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpymodule.o /tmp/tmpmvezsz89/tmp/tmpmvezsz89/src.linux-x86_64-3.6/fortranobject.o /tmp/tmpmvezsz89/umat_anl_ai.o /tmp/tmpmvezsz89/py_anl_ai.o /tmp/tmpmvezsz89/tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpy-f2pywrappers.o /tmp/tmpmvezsz89/tmp/tmpmvezsz89/src.linux-x86_64-3.6/umatpy-f2pywrappers2.o -L/usr/lib/gcc/x86_64-redhat-linux/8 -L/usr/lib/gcc/x86_64-redhat-linux/8 -L/usr/lib64 -lpython3.6m -lgfortran -o ./umatpy.cpython-36m-x86_64-linux-gnu.so
# Removing build directory /tmp/tmpmvezsz89

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from itertools import product
from scipy.interpolate import interp1d
from sklearn.metrics import r2_score

import umatpy

# %%
base_dir = '/home/lpacheco/biopolymer-networks/1_affnet_cl_ai'
os.chdir(base_dir)

# %%
tex_fonts = {
    # Use LaTeX to write all text
    # "text.usetex": True,
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 12,
    "font.size": 12,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10
}

# update to latex fonts
plt.rcParams.update(tex_fonts)

# %%
''' MATERIAL PROPERTIES '''

##### Penalty parameter (0) #####
K = 1000000000000.0 # 1000.0
##### Isotropic matrix (1-3) #####
C10 = 0.0 # 0.0
C01 = 0.0 # 0.0
PHI = 1.0 # Filament volume fraction 1.0
###### Single Filament (4-11) #####
L = 1.96 # Filament contour length [microm] 1.96
R0F = 1.63 # Filament initial end-to-end distance [microm] 1.63
R0C = 0.014 # CL initial end-to-end distance [microm] 0.014
ETA = 0.6666 # CL stiffness [0,1] 0.6666
MU0 = 11111111111111111111111138600.0 # Stretch modulus [pN] inf
BETA = 0.5 # 0.5
B0 = 294.0*16.0*1.38065e-5 # Bending stiffness (T*Lp*kb) [pN * microm**2] 294.0*16.0*1.38e-5
LAMBDA0 = 1.00 # Pre-stretch 1.00
##### Affine Network (12-13) #####
n = 7.66 # Isotropic filaments per unit volume [microm**-3] 7.66
B = 0.001 # Dispersion parameter 0.001

base_material_properties = [K,
    C10, C01, PHI,
    L, R0F, R0C, ETA, MU0, BETA, B0, LAMBDA0,
    n, B
]

mat_props_tex = ['$K$', '$C_{10}$', '$C_{01}$', '$\phi$', 
                 '$L$', '$r_{0,f}$', '$r_{0,c}$', '$\eta$', '$\mu_0$', '$\beta$', '$B_0$', '$\lambda_0$', 
                 '$n$', '$b$']

# Write material properties to a file
'''with open('material_properties.txt', 'w') as f:
    for prop in material_properties:
        f.write(f'{prop}\n')'''
# Out:
# "with open('material_properties.txt', 'w') as f:\n    for prop in material_properties:\n        f.write(f'{prop}\n')"

# %% [markdown]
# ## Auxiliary Functions

# %%
''' AUX FUNCTIONS '''

# Setting the deformation gradient
def dfgrd(def_mode:str, stretch:float):
    """
    Computes the deformation gradient F for simple deformation modes.

    INPUTS: 
        def_mode: str - Deformation mode ('U' uniaxial, 'SS(x/y)' simple shear along x/y directions)
        stretch(/shear): float
    OUTPUTS: 
        F: ndarray - Deformation gradient (3x3)
    """
    if def_mode not in ['U', 'SSx', 'SSy']:
        raise ValueError("Invalid deformation mode. Choose 'U', 'SSx', or 'SSy'.")
    
    if not isinstance(stretch, (int, float)):
        raise TypeError("Stretch/shear value must be a number.")

    F = np.eye(3)
    
    if def_mode == 'U':
        F[0,0] = stretch
        F[1,1] = 1/np.sqrt(stretch)
        F[2,2] = 1/np.sqrt(stretch)
    elif def_mode == 'SSx':
        F[0,1] = stretch
    elif def_mode == 'SSy':
        F[1,0] = stretch
    return F

# Function for sensitivity analysis
def sens_analysis(def_mode:str,
                  stretch: list, 
                  time: list, 
                  mat_props: list, id_props:list, range_props:dict, 
                  id_stress:int):
    ''' Performs a sensitivity analysis on the chosen parameters for the compliant CL actin network (material point).

    INPUTS: def_mode - deformation mode ('U' uniaxial, 'SS(x/y)' simple shear along x/y directions);
            stretch - [stretch_min, stretch_max, nsteps];
            time - [time_0, time_end, dtime];
            mat_props - list with the baseline material properties;
            id_props - indices of the material properties being studies in the array mat_props [i,j,k, ...];
            range_props - dict{'min':[imin, jmin, kmin...], 'max':[imax, jmax, kmax...], 'nstep':[int, int, int, ...]};
            id_stress - index of the target stress component [xx yy zz xy xz yz];

    OUTPUTS: stress - stress array as a function of given stretch values (i_n, j_n, k_n..., nsteps);
             map_props - array that maps each stress vector to the corresponding material properties being studied (i_n, j_n, k_n..., len(id_props))'''
    # List with all values for each property being studied
    sens_props, len_props, stress_flat = [], [], []
    stretch_arr = np.arange(stretch[0], stretch[1], (stretch[1]-stretch[0])/stretch[2])
    for i, _ in enumerate(id_props):
        aux_min = range_props['min'][i]
        aux_max = range_props['max'][i]
        aux_inc = range_props['nstep'][i]
        aux_list = np.linspace(aux_min, aux_max, aux_inc).tolist()
        len_props.append(len(aux_list))
        sens_props.append(aux_list)
    len_props.append(len(id_props))
    comb_props_flat = list(product(*sens_props))
    for i, comb in enumerate(comb_props_flat):
        kstep = 0
        aux_time, dtime = [time[0:2], time[2]]
        aux_stress = []
        for j, id in enumerate(id_props):
            mat_props[id] = comb[j]
        for k, stretch in enumerate(stretch_arr):
            kstep += k
            F = dfgrd(def_mode, stretch)
            stress = umatpy.run_umat_py(mat_props, F, aux_time, dtime, kstep)
            aux_time[0] += dtime
            aux_stress.append(stress[id_stress])
        stress_flat.append(aux_stress)
    map_props = np.array(comb_props_flat).reshape(len_props)
    aux_shape = len_props[:-1]
    aux_shape.append(len(stretch_arr))
    stress_curves = np.array(stress_flat).reshape(aux_shape)
    return map_props, stress_curves

# %% [markdown]
# ## Stress-Stretch curve

# %%
stretch_list, stress_list = [], []
material_properties = base_material_properties.copy()
material_properties[8] = 11111111111111138600.0

stretch_initial = 1.0
stretch_max = 1.28
nsteps = 100
dstretch = (stretch_max-stretch_initial)/nsteps

time = [0, 0]
dtime=0.1
kstep=1

stress_array = np.zeros((1, nsteps))
time = [0, 0]
kstep=1
for j, stretch in enumerate(np.arange(stretch_initial, stretch_max, dstretch)):
    F = dfgrd('U', stretch)
    stress = umatpy.run_umat_py(material_properties, F, time, dtime, kstep)
    stress_array[0,j] = stress[0]
    time[0] += dtime
    kstep += 1
stretch_array = np.arange(stretch_initial, stretch_max, dstretch)
stress_array[0,:]

plt.figure(figsize=(6,5))
plt.plot(stretch_array, stress_array[0,:])
plt.grid(alpha=0.3)
plt.xlabel('$\lambda$', fontsize=14)
plt.ylabel('$\sigma_{xx}$ (Pa)', fontsize=14)
# Out:
# Text(0, 0.5, '$\\sigma_{xx}$ (Pa)')

# %% [markdown]
# ## Sensitivity analysis

# %%
# Test if the sensitivity analysis function is working properly
material_properties = base_material_properties.copy()
'''range_dict = {'min':[1.96, 1.4, 0.01],
              'max':[2.16, 1.6, 0.014],
              'nstep':[3, 3, 3]}'''

# 1st plot data
range_dict = {'min':[0.4],
              'max':[0.8],
              'nstep':[3]}
map_array, curves = sens_analysis(def_mode='U', stretch=[1.0, 1.1, 100], time=[0,0,0.1], mat_props=material_properties, id_props=[7], range_props=range_dict, id_stress=0)
# print(map_array.shape, curves.shape)

# 2nd plot data
range_dict2 = {'min':[1.5],
              'max':[1.7],
              'nstep':[3]}
map_array2, curves2 = sens_analysis(def_mode='U', stretch=[1.0, 1.1, 100], time=[0,0,0.1], mat_props=material_properties, id_props=[5], range_props=range_dict2, id_stress=0)

# Sensitity analysis plots
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(9,4.5))
for i in range(3):
    ax1.plot(np.arange(1.0, 1.1, (1.1-1.0)/100), curves[i,:], label=mat_props_tex[7] + f' = {map_array[i].item():.2f}')
    ax2.plot(np.arange(1.0, 1.1, (1.1-1.0)/100), curves2[i,:], label=mat_props_tex[5] + f' = {map_array2[i].item():.2f}')

ax1.set_xlabel('$\lambda$', fontsize=14)
ax1.set_ylabel('$\sigma_{xx}$ (Pa)', fontsize=14)
ax1.set_title('Crosslinker relative stiffness')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=12)

ax2.set_xlabel('$\lambda$', fontsize=14)
ax2.set_ylabel('$\sigma_{xx}$ (Pa)', fontsize=14)
ax2.set_title('Filament end-to-end distance')
ax2.grid(True, alpha=0.3)
ax2.legend(fontsize=12)

# fig.savefig('00plot.png', bbox_inches='tight')

# %%
# Sensitivity analysis - Studying more than 1 parameter
material_properties = base_material_properties.copy()
stretch_aux_list = [1.0, 1.1, 100]
range_dict = {'min':[1.96, 1.4, 0.01],
              'max':[2.1, 1.6, 0.014],
              'nstep':[3, 3, 3]}

map_array, curves = sens_analysis(def_mode='U', stretch = stretch_aux_list, time=[0,0,0.1], mat_props=material_properties, id_props=[4,5,6], range_props=range_dict, id_stress=0)

# %%
curves_for_df = curves.reshape(-1,100)
curve_id = np.arange(curves_for_df.shape[0])
stretches = np.tile(np.arange(stretch_aux_list[0], stretch_aux_list[1], (stretch_aux_list[1]-stretch_aux_list[0])/stretch_aux_list[2]), curves_for_df.shape[0])

df = pd.DataFrame({
    'curve_id': np.repeat(curve_id, 100),
    'stretch': stretches, 
    'stress': curves_for_df.flatten()
    })

plt.figure(figsize=(6,4))
sns.lineplot(x='stretch', y='stress', data=df, ci='sd')
plt.xlabel('$\lambda$')
plt.ylabel('$\sigma_{xx}$ (Pa)')
# Out:
# Text(0, 0.5, '$\\sigma_{xx}$ (Pa)')

# %% [markdown]
# ## Model Validation
#
# Comparison with results from "An affine continuum mechanical model for cross-linked F-actin networks with compliant linker proteins" (Holzapfel, Unterberger and Ogden, 2014) and results obtained using a single unit cube element in Abaqus.

# %%
# Get abaqus results
os.chdir('test_in_abaqus/np_outputs')
abq_sh_033 = np.load('output_0.npy')
abq_sh_067 = np.load('output_1.npy')
abq_sh_100 = np.load('output_2.npy')
abq_list = [abq_sh_100, abq_sh_067, abq_sh_033]
os.chdir(base_dir)

# %%
##### Normal stress vs Shear deformation (Figure 6a) #####
material_properties = base_material_properties.copy()

# Shear
shear_initial = 0
shear_max = 0.35
nsteps = 100
dshear = (shear_max-shear_initial)/nsteps
# shear_array = np.arange(shear_initial, shear_max, dshear)
shear_array = np.linspace(shear_initial, shear_max, nsteps)
dtime = 0.01
# CL stiffness
etac_array = np.array([1, 2/3, 1/3])
# Stress
stress_array = np.zeros((len(etac_array), nsteps))
interp_list, r2_list = [], []

for i, etac in enumerate(etac_array):
    material_properties[7] = etac
    time = [0,0]
    for j, shear in enumerate(shear_array):
        kstep = j + 1
        F = dfgrd('SSx', shear)
        stress = umatpy.run_umat_py(material_properties, F, time, dtime, kstep)
        stress_array[i,j] = stress[1]-stress[2]
        time[0] += dtime

plt.figure(figsize=(6,5))
plt_colors = ['red', 'blue', 'green']

files_6a = sorted([file for file in os.listdir('Holzapfel2014_plots') if '6a' in file], reverse=True)
os.chdir('Holzapfel2014_plots')
for j, file in enumerate(files_6a):
    df = pd.read_csv(file, header=None, names=['x', 'y'])
    eta = etac_array[j]
    int_fun = interp1d(shear_array, stress_array[j,:], kind=5)
    stress_interp = int_fun([val for val in df['x'] if val < (shear_max - dshear)])
    r2 = r2_score(df['y'][:len(stress_interp)], stress_interp)
    r2_list.append(r2)
    plt.plot(df['x'], df['y'], color=plt_colors[j], linestyle='--')

for i, eta in enumerate(etac_array):
    r2 = r2_list[i]
    plt.plot(shear_array, stress_array[i,:], label=f'$\eta = $ {eta:.2f}' + f', $R^2=${r2:.3f}', color=plt_colors[i])

## Abaqus
for i, output in enumerate(abq_list):
    x = np.arctan(output[0,:])
    y = output[4,:]
    plt.plot(x, y, color=plt_colors[i], linestyle='dotted')
##

df2 = pd.read_csv('holz2014_4a_095.csv', header=None, names=['x', 'y'])
# plt.plot(df2['x'], df2['y'], color='orange', linestyle='-.', alpha=1.)
# df3 = pd.read_csv('holz2014_4b_095.csv', header=None, names=['x', 'y'])
# plt.plot(df3['x'], df3['y'], color='grey', linestyle='-.', alpha=1.)
os.chdir('..')
dashed_line = plt.plot([], [], color='black', linestyle='--', label='Holzapfel 2014')
dotted_line = plt.plot([], [], color='black', linestyle='dotted', label='Abaqus (unit cube)')
# dashdot_line = plt.plot([], [], color='orange', linestyle='-.', label='Holzapfel 2014 (w/o CLs)')
plt.legend()
plt.grid(alpha=0.3)
plt.ylim((0,20))
plt.xlabel('Amount of shear $\gamma$ (-)', fontsize=14)
plt.ylabel('$\sigma_{yy}$ (Pa)', fontsize=14)
# plt.savefig('./figures/fig1.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, '$\\sigma_{yy}$ (Pa)')

# %%
##### Shear stress vs Shear deformation (Figure 6b) #####
material_properties = base_material_properties.copy()
# material_properties[6] = 0
# Shear
shear_initial = 0
shear_max = 0.35
nsteps = 100
dshear = (shear_max-shear_initial)/nsteps
shear_array = np.arange(shear_initial, shear_max, dshear)
dtime = 0.0001
# CL stiffness
etac_array = np.array([1, 2/3, 1/3])
# Stress
stress_array = np.zeros((len(etac_array), nsteps))
interp_list, r2_list = [], []

for i, etac in enumerate(etac_array):
    material_properties[7] = etac
    time = [0,0]
    for j, shear in enumerate(shear_array):
        kstep = j + 1
        F = dfgrd('SSx', shear)
        stress = umatpy.run_umat_py(material_properties, F, time, dtime, kstep)
        stress_array[i,j] = stress[3]
        time[0] += dtime

plt.figure(figsize=(6,5))
plt_colors = ['red', 'blue', 'green']

files_6b = sorted([file for file in os.listdir('Holzapfel2014_plots') if '6b' in file], reverse=True)
os.chdir('Holzapfel2014_plots')
for j, file in enumerate(files_6b):
    df = pd.read_csv(file, header=None, names=['x', 'y'])
    eta = etac_array[j]
    int_fun = interp1d(shear_array, stress_array[j,:], kind=5)
    stress_interp = int_fun([val for val in df['x'] if val < (shear_max - dshear)])
    r2 = r2_score(df['y'][:len(stress_interp)], stress_interp)
    r2_list.append(r2)
    plt.plot(df['x'], df['y'], color=plt_colors[j], linestyle='--')

for i, eta in enumerate(etac_array):
    r2 = r2_list[i]
    plt.plot(shear_array, stress_array[i,:], label=f'$\eta = $ {eta:.2f}' + f', $R^2=${r2:.3f}', color=plt_colors[i])

## Abaqus
for i, output in enumerate(abq_list):
    x = np.arctan(output[0,:])
    y = output[5,:]
    plt.plot(x, y, color=plt_colors[i], linestyle='dotted')
##

df2 = pd.read_csv('holz2014_4b_095.csv', header=None, names=['x', 'y'])
# plt.plot(df2['x'], df2['y'], color='orange', linestyle='-.', alpha=1.)
os.chdir('..')
dashed_line = plt.plot([], [], color='black', linestyle='--', label='Holzapfel 2014')
dotted_line = plt.plot([], [], color='black', linestyle='dotted', label='Abaqus (unit cube)')
# dashdot_line = plt.plot([], [], color='orange', linestyle='-.', label='Holzapfel 2014 (w/o CLs)')
plt.legend()
plt.grid(alpha=0.3)
plt.ylim((0,20))
plt.xlabel('Amount of shear $\gamma$ (-)', fontsize=14)
plt.ylabel('$\\tau_{xy}$ (Pa)', fontsize=14)
# plt.savefig('./figures/fig3.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, '$\\tau_{xy}$ (Pa)')

# %% [markdown]
# ## Studying different contributions (AN and IM)
#
# - Study the contribution of the Affine Network (AN), Non-affine Network (NA - not implemented) and Isotropic Ground-Substance/Matrix (IM)
# - AN is only considered when the density of contractile bundles/isotropic filaments $n$>0.
# - IM is only considered when the filament volume fraction $\varphi$<1.

# %%
# Common variables
stretch_array = np.linspace(1., 1.2, 200)
shear_array = np.linspace(0., 0.35, 200)
time = [0, 0]
dtime = 0.1

##### AN contribution #####
material_properties_AN = base_material_properties.copy()
stress_AN_uni, stress_AN_shear = [], [] 

for i, stretch in enumerate(stretch_array):
    kstep = i + 1
    F = dfgrd('U', stretch)
    stress = umatpy.run_umat_py(material_properties_AN, F, time, dtime, kstep)
    stress_AN_uni.append(stress[0])
    time[0] = (i+1)*dtime

for j, shear in enumerate(shear_array):
    kstep = j + 1
    F = dfgrd('SSx', shear)
    stress = umatpy.run_umat_py(material_properties_AN, F, time, dtime, kstep)
    stress_AN_shear.append(stress[3])
    time[0] = (j+1)*dtime

stress_AN_uni = np.array(stress_AN_uni)
stress_AN_shear = np.array(stress_AN_shear)

print(stress_AN_uni.shape, stress_AN_shear.shape)
# Out:
# (200,) (200,)

# %%
# IM contribution
material_properties_IM = base_material_properties.copy()
material_properties_IM[1:4] = [3.5, 2, 0.5]
material_properties_IM[12] = 0
stress_IM_uni, stress_IM_shear = [], [] 

for i, stretch in enumerate(stretch_array):
    kstep = i + 1
    F = dfgrd('U', stretch)
    stress = umatpy.run_umat_py(material_properties_IM, F, time, dtime, kstep)
    stress_IM_uni.append(stress[0])
    time[0] = (i+1)*dtime

for j, shear in enumerate(shear_array):
    kstep = j + 1
    F = dfgrd('SSx', shear)
    stress = umatpy.run_umat_py(material_properties_IM, F, time, dtime, kstep)
    stress_IM_shear.append(stress[3])
    time[0] = (j+1)*dtime

stress_IM_uni = np.array(stress_IM_uni)
stress_IM_shear = np.array(stress_IM_shear)

print(stress_IM_uni.shape, stress_IM_shear.shape)
# Out:
# (200,) (200,)

# %%
# Sum of separate/isolated contributions
stress_sum_uni = stress_AN_uni + stress_IM_uni
stress_sum_shear = stress_AN_shear + stress_IM_shear

# Running the UMAT considering both AN and IM contributions
material_properties = base_material_properties.copy()
material_properties[1:4] = [3.5, 2, 0.5]
stress_uni, stress_shear = [], [] 

for i, stretch in enumerate(stretch_array):
    kstep = i + 1
    F = dfgrd('U', stretch)
    stress = umatpy.run_umat_py(material_properties, F, time, dtime, kstep)
    stress_uni.append(stress[0])
    time[0] = (i+1)*dtime

for j, shear in enumerate(shear_array):
    kstep = j + 1
    F = dfgrd('SSx', shear)
    stress = umatpy.run_umat_py(material_properties, F, time, dtime, kstep)
    stress_shear.append(stress[3])
    time[0] = (j+1)*dtime

stress_uni = np.array(stress_uni)
stress_shear = np.array(stress_shear)

print(stress_uni.shape, stress_shear.shape)
# Out:
# (200,) (200,)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(stretch_array, stress_AN_uni, label = 'AN')
axs[0].plot(stretch_array, stress_IM_uni, label = 'IM')
axs[0].plot(stretch_array, stress_uni, label = 'AN+IM')
axs[0].set_xlabel('$\lambda$')
axs[0].set_ylabel('$\sigma_{xx}$ (Pa)')
axs[0].set_title('Uniaxial')
axs[0].legend()

axs[1].plot(shear_array, stress_AN_shear, label = 'AN')
axs[1].plot(shear_array, stress_IM_shear, label = 'IM')
axs[1].plot(shear_array, stress_shear, label = 'AN+IM')
axs[1].set_xlabel('$\gamma$')
axs[1].set_ylabel('$\\tau_{xy}$ (Pa)')
axs[1].set_title('Simple Shear')

for ax in axs:
    ax.grid(True, alpha=0.3)

# %%
print(np.all(stress_sum_uni - stress_uni <= abs(1e-3)))
print(np.all(stress_sum_shear - stress_shear <= abs(1e-14)))
# Out:
# True
# True

# %%
stress_sum_uni[:20], stress_uni[:20], len(stress_sum_uni), len(stress_uni)
# Out:
# (array([8.88178420e-16, 2.59141175e-02, 5.11086116e-02, 7.69220823e-02,
#         1.02908540e-01, 1.28628316e-01, 1.55415087e-01, 1.81494141e-01,
#         2.08644909e-01, 2.35538546e-01, 2.63062101e-01, 2.89888478e-01,
#         3.17351053e-01, 3.45009323e-01, 3.72864280e-01, 4.01361713e-01,
#         4.28730352e-01, 4.57636176e-01, 4.86305345e-01, 5.15180913e-01]),
#  array([8.88178420e-16, 2.56920729e-02, 5.11086116e-02, 7.69220823e-02,
#         1.02908540e-01, 1.28850361e-01, 1.55415087e-01, 1.81716186e-01,
#         2.08644909e-01, 2.35538546e-01, 2.62840057e-01, 2.89888478e-01,
#         3.17351053e-01, 3.45009323e-01, 3.72864280e-01, 4.01139668e-01,
#         4.28952396e-01, 4.57636176e-01, 4.86305345e-01, 5.15180913e-01]),
#  200,
#  200)

# %%
# !gfortran -o 00_test.o 00_test.f90
# !./00_test.o

# %%
# Getting the outputs with subprocess
# result = subprocess.run("./00_new_anl_ai.o", shell=True, stdout=subprocess.PIPE)
# Get the output from the completed process
# fortran_output = result.stdout.decode("utf-8")
# Process the Fortran output as needed
# num_output = [float(out) for out in fortran_output.split()]
# stretch = num_output[0]
# stress = np.array(num_output[1:7])
# ddsdde = np.array(num_output[7:])

# %%
### force - stretch relation (inextensible)
def force(stretch, L, r0, beta, B0):
    a = L/r0
    ff = ((a-1)/(a-stretch))**(1/beta)-1
    force = ff*B0*np.pi**2/L**2
    return force

x_stretch = np.arange(1,1.2,0.002)
x_r = x_stretch * 10.17
f = force(x_stretch, 1.96, 1.63, 0.5, 294.0*16.0*1.38e-5)

# %%
plt.plot(x_r, f)
plt.yscale('log')
plt.xlim(11.1,11.3)
plt.xticks([11.1,11.15,11.2,11.25,11.3])
plt.ylim(0.6,200)
plt.axvline(x=11.25, linestyle='--', color='orange')
plt.grid(True, alpha=0.3)
plt.xlabel('$r$ ($\mu \mathrm{m})$')
plt.ylabel('$f$ (pN)')
# Out:
# Text(0, 0.5, '$f$ (pN)')

# %%
x_stretch
# Out:
# array([1.   , 1.002, 1.004, 1.006, 1.008, 1.01 , 1.012, 1.014, 1.016,
#        1.018, 1.02 , 1.022, 1.024, 1.026, 1.028, 1.03 , 1.032, 1.034,
#        1.036, 1.038, 1.04 , 1.042, 1.044, 1.046, 1.048, 1.05 , 1.052,
#        1.054, 1.056, 1.058, 1.06 , 1.062, 1.064, 1.066, 1.068, 1.07 ,
#        1.072, 1.074, 1.076, 1.078, 1.08 , 1.082, 1.084, 1.086, 1.088,
#        1.09 , 1.092, 1.094, 1.096, 1.098, 1.1  , 1.102, 1.104, 1.106,
#        1.108, 1.11 , 1.112, 1.114, 1.116, 1.118, 1.12 , 1.122, 1.124,
#        1.126, 1.128, 1.13 , 1.132, 1.134, 1.136, 1.138, 1.14 , 1.142,
#        1.144, 1.146, 1.148, 1.15 , 1.152, 1.154, 1.156, 1.158, 1.16 ,
#        1.162, 1.164, 1.166, 1.168, 1.17 , 1.172, 1.174, 1.176, 1.178,
#        1.18 , 1.182, 1.184, 1.186, 1.188, 1.19 , 1.192, 1.194, 1.196,
#        1.198])
